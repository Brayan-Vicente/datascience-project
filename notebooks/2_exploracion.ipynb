# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df = pd.read_csv('data/clean_compras.csv')

# %%
compras_df.head(5)
# Out:
#    NUM BEN                                    BENEFICIARIO           RFC  \
# 0   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# 2  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR    1019110.0
# 3  REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR    1019110.0
# 4  REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR  299001496.0
#
#         FECHA   IMPORTE          SHEET
# 0  2020-12-11  14911.80  GASTOS VARIOS
# 1  2020-12-11   2528.80  GASTOS VARIOS
# 2  2020-12-11   8500.02  GASTOS VARIOS
# 3  2020-12-11   2400.01  GASTOS VARIOS
# 4  2020-12-23   1537.00  GASTOS VARIOS

# %% [markdown]
# ## Visión general del dataset

# %%
compras_df.columns
# Out:
# Index(['NUM BEN', 'BENEFICIARIO', 'RFC', 'FACTURA', 'CONTRATO', 'CONCEPTO',
#        'TIPO', '# OP', 'FECHA', 'IMPORTE', 'SHEET'],
#       dtype='object')

# %%
compras_df.dtypes
# Out:
# NUM BEN           int64
# BENEFICIARIO     object
# RFC              object
# FACTURA          object
# CONTRATO         object
# CONCEPTO         object
# TIPO             object
# # OP            float64
# FECHA            object
# IMPORTE         float64
# SHEET            object
# dtype: object

# %%
compras_df.describe()
# Out:
#              NUM BEN          # OP       IMPORTE
# count    1540.000000  1.540000e+03  1.540000e+03
# mean   203914.777273  1.920050e+08  6.263179e+05
# std     92435.932025  1.411189e+08  4.666912e+06
# min    110152.000000  1.019042e+06  8.600000e-01
# 25%    116223.000000  1.019144e+06  2.987000e+03
# 50%    203013.000000  2.980000e+08  1.235584e+04
# 75%    311250.000000  3.000001e+08  1.130583e+05
# max    370012.000000  6.040001e+08  1.267303e+08

# %% [markdown]
# compras_df = compras_df[['BENEFICIARIO', 'FACTURAS', 'CONTRATO', 'CONCEPTO', 'TIPO', '# OP', 'FECHA', 'IMPORTE','SHEET']]

# %% [markdown]
# ## Análisis unidimencional de las variables

# %%
compras_df['SHEET'].value_counts()
# Out:
# SHEET
# CONTRATISTAS Y FDO FED    724
# GASTOS VARIOS             690
# COMUNICACION               71
# SERV. PERS.                46
# SERV PPROF                  9
# Name: count, dtype: int64

# %%
len(compras_df['CONCEPTO'].unique())
# Out:
# 1396

# %%
compras_df['BENEFICIARIO'].value_counts()[0:10]
# Out:
# BENEFICIARIO
# CAMARA MEXICANA DE LA INDUSTRIA DE LA CONSTRUCCION    266
# AUTOKAM REGIOMONTANA,S.A.DE C.V.                      101
# CAR ONE MONTERREY, S.A. DE C.V.                        78
# PEREZ RIOS RAMIRO                                      58
# S.I.M.E.P.R.O.D.E.                                     50
# INTERASFALTOS, S.A. DE C.V.                            45
# GRUPO COYOTE MONTERREY, S.A. DE C.V.                   43
# SERVICIO TECNICO CHURUBUSCO, S.A. DE C.V.              30
# CFE SUMINISTRADOR DE SERVICIOS BASICOS                 29
# CORDERO MACIAS SILVESTRE GUADALUPE                     27
# Name: count, dtype: int64

# %%
compras_df['IMPORTE'].hist()
# Out:
# <Axes: >

# %%
compras_df[compras_df['IMPORTE']< compras_df['IMPORTE'].quantile(0.95)]['IMPORTE'].hist()
# Out:
# <Axes: >

# %%
compras_df[compras_df['IMPORTE']< compras_df['IMPORTE'].quantile(0.95)]['IMPORTE'].hist(bins=50)
# Out:
# <Axes: >

# %%
compras_df[compras_df['IMPORTE']< compras_df['IMPORTE'].quantile(0.95)].head(5)
# Out:
#    NUM BEN                                    BENEFICIARIO           RFC  \
# 0   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# 2  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR    1019110.0
# 3  REEMPLAZO DE  DOS RINES  (14). PATRIMONIO 8007...   TR    1019110.0
# 4  REEMPLAZO E INSTALACION DE RIN 14. PATRIMONIO ...   TR  299001496.0
#
#         FECHA   IMPORTE          SHEET
# 0  2020-12-11  14911.80  GASTOS VARIOS
# 1  2020-12-11   2528.80  GASTOS VARIOS
# 2  2020-12-11   8500.02  GASTOS VARIOS
# 3  2020-12-11   2400.01  GASTOS VARIOS
# 4  2020-12-23   1537.00  GASTOS VARIOS

# %% [markdown]
# ## Análisis multidimencional de las variables

# %%
sum_importe_beneficiario = compras_df.groupby('BENEFICIARIO').sum()['IMPORTE']

# %%
sum_importe_beneficiario.reset_index().sort_values(by='IMPORTE', ascending=False).iloc[0:10].plot(kind='bar', x='BENEFICIARIO', y='IMPORTE')
# Out:
# <Axes: xlabel='BENEFICIARIO'>

# %%
importa_df = compras_df.fillna(0, inplace=False)['IMPORTE']

# %% [markdown]
# importa_df = reset_index().sort_values(by='IMPORTE', asending=False).iloc[0:10].plot(kind='bar', x='SHEET', y='IMPORTE')

# %%
sum_importe_fecha = compras_df.groupby('FECHA').sum()['IMPORTE']

# %%
sum_importe_fecha
# Out:
# FECHA
# 2020-12-01    2.453181e+04
# 2020-12-02    3.000000e+04
# 2020-12-03    1.313241e+05
# 2020-12-04    7.432247e+07
# 2020-12-07    1.815018e+06
# 2020-12-08    1.519824e+08
# 2020-12-09    4.659596e+05
# 2020-12-10    1.207010e+06
# 2020-12-11    1.127524e+08
# 2020-12-14    3.692338e+05
# 2020-12-15    1.826510e+04
# 2020-12-16    2.504067e+06
# 2020-12-17    1.735205e+08
# 2020-12-18    1.568875e+08
# 2020-12-21    9.441760e+05
# 2020-12-22    6.814845e+07
# 2020-12-23    3.328571e+07
# 2020-12-28    1.204764e+08
# 2020-12-29    2.050000e+05
# 2020-12-30    6.435889e+07
# 2020-12-31    1.080281e+06
# Name: IMPORTE, dtype: float64

# %%
compras_gastos_df = compras_df[compras_df['SHEET'] == 'GASTOS VARIOS']

# %%
# Histograma
compras_gastos_df['IMPORTE'].hist(bins=50)
# Out:
# <Axes: >

# %%
compras_df[compras_df['BENEFICIARIO'] == 'MUNICIPIO DE LA CIUDAD DE MONTERREY']
# Out:
#       NUM BEN                         BENEFICIARIO           RFC  \
# 367    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 368    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 369    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 370    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 371    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 372    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 373    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 374    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 375    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 376    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 377    206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 1034   206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 1035   206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 1036   206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 1037   206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
# 1038   206894  MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2
#
#                     FACTURA   CONTRATO  \
# 367   2020-23-A-158004-1734  NO APLICA
# 368   2020-23-B-158004-1735  NO APLICA
# 369   2020-23-C-158004-1733  NO APLICA
# 370   2020-24-A-158004-1760  NO APLICA
# 371   2020-24-A-158004-1780  NO APLICA
# 372   2020-24-B-158004-1761  NO APLICA
# 373   2020-24-B-158004-1781  NO APLICA
# 374   2020-24-C-158004-1759  NO APLICA
# 375   2020-24-C-158004-1779  NO APLICA
# 376              158002-470  NO APLICA
# 377              158002-472  NO APLICA
# 1034   PRO-01-12-153001-173  NO APLICA
# 1035   PRO-02-12-153001-176  NO APLICA
# 1036   PRO-03-12-153001-178  NO APLICA
# 1037   PRO-04-12-153001-180  NO APLICA
# 1038   PRO-05-12-153001-183  NO APLICA
#
#                                                CONCEPTO TIPO         # OP  \
# 367   PAGO DE NÓMINA PERIODO: 23-2020, BANCO: BANCA ...   TR   11000196.0
# 368   PAGO DE NÓMINA PERIODO: 23-2020, BANCO: BANCO ...   TR  231000103.0
# 369   PAGO DE NÓMINA PERIODO: 23-2020, BANCO: BANCO ...   TR  240000108.0
# 370   PAGO DE NÓMINA PERIODO: 24-2020, BANCO: BANCA ...   TR   11000197.0
# 371   PAGO DE NÓMINA PERIODO: 24-2020-E1, BANCO: BAN...   TR   11000198.0
# 372   PAGO DE NÓMINA PERIODO: 24-2020, BANCO: BANCO ...   TR  231000104.0
# 373   PAGO DE NÓMINA PERIODO: 24-2020-E1, BANCO: BAN...   TR  231000105.0
# 374   PAGO DE NÓMINA PERIODO: 24-2020, BANCO: BANCO ...   TR  240000109.0
# 375   PAGO DE NÓMINA PERIODO: 24-2020-E1, BANCO: BAN...   TR  240000110.0
# 376   FINIQUITO DE FONDO OPERATIVO DE LA SECRETARÍA ...   CH  299000198.0
# 377   FINIQUITO DE CAJA CHICA DE LA SECRETARÍA DE OB...   CH  299000200.0
# 1034                                  PROGRAMA PROREGIO   TR  308000030.0
# 1035                                  PROGRAMA PROREGIO   TR  308000031.0
# 1036                                  PROGRAMA PROREGIO   TR  308000032.0
# 1037                      PROGRAMA PROREGIO EMPRESARIAL   TR  308000033.0
# 1038                                  PROGRAMA PROREGIO   TR  308000034.0
#
#            FECHA      IMPORTE                   SHEET
# 367   2020-12-17  73864368.92           GASTOS VARIOS
# 368   2020-12-17  76352493.81           GASTOS VARIOS
# 369   2020-12-17  19246138.70           GASTOS VARIOS
# 370   2020-12-28  36101891.39           GASTOS VARIOS
# 371   2020-12-28     27443.46           GASTOS VARIOS
# 372   2020-12-28  33579364.01           GASTOS VARIOS
# 373   2020-12-28    132688.02           GASTOS VARIOS
# 374   2020-12-28  13362855.08           GASTOS VARIOS
# 375   2020-12-28     17925.96           GASTOS VARIOS
# 376   2020-12-30      1439.20           GASTOS VARIOS
# 377   2020-12-30      2847.79           GASTOS VARIOS
# 1034  2020-12-04      7875.00  CONTRATISTAS Y FDO FED
# 1035  2020-12-11      9375.00  CONTRATISTAS Y FDO FED
# 1036  2020-12-21      8625.00  CONTRATISTAS Y FDO FED
# 1037  2020-12-28      4125.00  CONTRATISTAS Y FDO FED
# 1038  2020-12-30      4125.00  CONTRATISTAS Y FDO FED

# %%
compras_df[compras_df['BENEFICIARIO'] == 'MUNICIPIO DE LA CIUDAD DE MONTERREY'].value_counts()
# Out:
# NUM BEN  BENEFICIARIO                         RFC           FACTURA                CONTRATO   CONCEPTO                                                                                                                                    TIPO  # OP         FECHA       IMPORTE      SHEET
# 206894   MUNICIPIO DE LA CIUDAD DE MONTERREY  MCM610101PT2  158002-470             NO APLICA  FINIQUITO DE FONDO OPERATIVO DE LA SECRETARÍA DE OBRAS PÚBLICAS A NOMBRE DE JOSÉ NAZARIO  PINEDA OSORIO RECIBO DE INGRESOS CON FOLIO:59793  CH    299000198.0  2020-12-30  1439.20      GASTOS VARIOS             1
#                                                             158002-472             NO APLICA  FINIQUITO DE CAJA CHICA DE LA SECRETARÍA DE OBRAS PÚBLICAS A NOMBRE DE JOSÉ NAZARIO PINEDA OSORIO  RECIBO DE INGRESOS CON FOLIO:59794       CH    299000200.0  2020-12-30  2847.79      GASTOS VARIOS             1
#                                                             2020-23-A-158004-1734  NO APLICA  PAGO DE NÓMINA PERIODO: 23-2020, BANCO: BANCA AFIRME, S.A., TIPO DE PAGO: TRANSFERENCIA                                                     TR    11000196.0   2020-12-17  73864368.92  GASTOS VARIOS             1
#                                                             2020-23-B-158004-1735  NO APLICA  PAGO DE NÓMINA PERIODO: 23-2020, BANCO: BANCO MERCANTIL DEL NORTE S.A., TIPO DE PAGO: TRANSFERENCIA                                         TR    231000103.0  2020-12-17  76352493.81  GASTOS VARIOS             1
#                                                             2020-23-C-158004-1733  NO APLICA  PAGO DE NÓMINA PERIODO: 23-2020, BANCO: BANCO MERCANTIL DEL NORTE S.A., TIPO DE PAGO: CHEQUE                                                TR    240000108.0  2020-12-17  19246138.70  GASTOS VARIOS             1
#                                                             2020-24-A-158004-1760  NO APLICA  PAGO DE NÓMINA PERIODO: 24-2020, BANCO: BANCA AFIRME, S.A., TIPO DE PAGO: TRANSFERENCIA                                                     TR    11000197.0   2020-12-28  36101891.39  GASTOS VARIOS             1
#                                                             2020-24-A-158004-1780  NO APLICA  PAGO DE NÓMINA PERIODO: 24-2020-E1, BANCO: BANCA AFIRME, S.A., TIPO DE PAGO: TRANSFERENCIA                                                  TR    11000198.0   2020-12-28  27443.46     GASTOS VARIOS             1
#                                                             2020-24-B-158004-1761  NO APLICA  PAGO DE NÓMINA PERIODO: 24-2020, BANCO: BANCO MERCANTIL DEL NORTE S.A., TIPO DE PAGO: TRANSFERENCIA                                         TR    231000104.0  2020-12-28  33579364.01  GASTOS VARIOS             1
#                                                             2020-24-B-158004-1781  NO APLICA  PAGO DE NÓMINA PERIODO: 24-2020-E1, BANCO: BANCO MERCANTIL DEL NORTE S.A., TIPO DE PAGO: TRANSFERENCIA                                      TR    231000105.0  2020-12-28  132688.02    GASTOS VARIOS             1
#                                                             2020-24-C-158004-1759  NO APLICA  PAGO DE NÓMINA PERIODO: 24-2020, BANCO: BANCO MERCANTIL DEL NORTE S.A., TIPO DE PAGO: CHEQUE                                                TR    240000109.0  2020-12-28  13362855.08  GASTOS VARIOS             1
#                                                             2020-24-C-158004-1779  NO APLICA  PAGO DE NÓMINA PERIODO: 24-2020-E1, BANCO: BANCO MERCANTIL DEL NORTE S.A., TIPO DE PAGO: CHEQUE                                             TR    240000110.0  2020-12-28  17925.96     GASTOS VARIOS             1
#                                                             PRO-01-12-153001-173   NO APLICA  PROGRAMA PROREGIO                                                                                                                           TR    308000030.0  2020-12-04  7875.00      CONTRATISTAS Y FDO FED    1
#                                                             PRO-02-12-153001-176   NO APLICA  PROGRAMA PROREGIO                                                                                                                           TR    308000031.0  2020-12-11  9375.00      CONTRATISTAS Y FDO FED    1
#                                                             PRO-03-12-153001-178   NO APLICA  PROGRAMA PROREGIO                                                                                                                           TR    308000032.0  2020-12-21  8625.00      CONTRATISTAS Y FDO FED    1
#                                                             PRO-04-12-153001-180   NO APLICA  PROGRAMA PROREGIO EMPRESARIAL                                                                                                               TR    308000033.0  2020-12-28  4125.00      CONTRATISTAS Y FDO FED    1
#                                                             PRO-05-12-153001-183   NO APLICA  PROGRAMA PROREGIO                                                                                                                           TR    308000034.0  2020-12-30  4125.00      CONTRATISTAS Y FDO FED    1
# Name: count, dtype: int64

# %%
compras_sheet_beneficiario = compras_df.groupby(['BENEFICIARIO', 'SHEET']).sum() ['IMPORTE'].sort_values().unstack('SHEET')

# %%
top_beneficiarios = compras_df.groupby('BENEFICIARIO')['IMPORTE'].sum().sort_values(ascending=False).index[0:10]

# %%
compras_sheet_beneficiario.loc[top_beneficiarios].plot.bar(stacked=True)
# Out:
# <Axes: xlabel='BENEFICIARIO'>

# %% [markdown]
# ## Análisis de texto

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('spanish'))
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 'esté', 'estés', 'estemos', 'estéis', 'estén', 'estaré', 'estarás', 'estará', 'estaremos', 'estaréis', 'estarán', 'estaría', 'estarías', 'estaríamos', 'estaríais', 'estarían', 'estaba', 'estabas', 'estábamos', 'estabais', 'estaban', 'estuve', 'estuviste', 'estuvo', 'estuvimos', 'estuvisteis', 'estuvieron', 'estuviera', 'estuvieras', 'estuviéramos', 'estuvierais', 'estuvieran', 'estuviese', 'estuvieses', 'estuviésemos', 'estuvieseis', 'estuviesen', 'estando', 'estado', 'estada', 'estados', 'estadas', 'estad', 'he', 'has', 'ha', 'hemos', 'habéis', 'han', 'haya', 'hayas', 'hayamos', 'hayáis', 'hayan', 'habré', 'habrás', 'habrá', 'habremos', 'habréis', 'habrán', 'habría', 'habrías', 'habríamos', 'habríais', 'habrían', 'había', 'habías', 'habíamos', 'habíais', 'habían', 'hube', 'hubiste', 'hubo', 'hubimos', 'hubisteis', 'hubieron', 'hubiera', 'hubieras', 'hubiéramos', 'hubierais', 'hubieran', 'hubiese', 'hubieses', 'hubiésemos', 'hubieseis', 'hubiesen', 'habiendo', 'habido', 'habida', 'habidos', 'habidas', 'soy', 'eres', 'es', 'somos', 'sois', 'son', 'sea', 'seas', 'seamos', 'seáis', 'sean', 'seré', 'serás', 'será', 'seremos', 'seréis', 'serán', 'sería', 'serías', 'seríamos', 'seríais', 'serían', 'era', 'eras', 'éramos', 'erais', 'eran', 'fui', 'fuiste', 'fue', 'fuimos', 'fuisteis', 'fueron', 'fuera', 'fueras', 'fuéramos', 'fuerais', 'fueran', 'fuese', 'fueses', 'fuésemos', 'fueseis', 'fuesen', 'sintiendo', 'sentido', 'sentida', 'sentidos', 'sentidas', 'siente', 'sentid', 'tengo', 'tienes', 'tiene', 'tenemos', 'tenéis', 'tienen', 'tenga', 'tengas', 'tengamos', 'tengáis', 'tengan', 'tendré', 'tendrás', 'tendrá', 'tendremos', 'tendréis', 'tendrán', 'tendría', 'tendrías', 'tendríamos', 'tendríais', 'tendrían', 'tenía', 'tenías', 'teníamos', 'teníais', 'tenían', 'tuve', 'tuviste', 'tuvo', 'tuvimos', 'tuvisteis', 'tuvieron', 'tuviera', 'tuvieras', 'tuviéramos', 'tuvierais', 'tuvieran', 'tuviese', 'tuvieses', 'tuviésemos', 'tuvieseis', 'tuviesen', 'teniendo', 'tenido', 'tenida', 'tenidos', 'tenidas', 'tened']
# [nltk_data] Downloading package stopwords to C:\Users\Brayan
# [nltk_data]     Vicente\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
textos_compras = ''
for row in compras_df['CONCEPTO']: 
    textos_compras = textos_compras + ' ' + row

# %%
stopwords_list = stopwords.words('spanish') + ['2020', 'cont', 'millar', 'dpp', 'est', 'op', 'ret', 'mty', 'icom']

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\brayan vicente\appdata\roaming\python\python311\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\programs\anaconda\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\programs\anaconda\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\programs\anaconda\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programs\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programs\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
textos_compras = ' '.join([x for x in textos_compras.strip().lower().split(' ') if x not in stopwords_list and len (x)>4])

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color='black')
wc.generate(textos_compras)

plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()
